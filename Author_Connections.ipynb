# %% [markdown]
# # Connections of Top Authors and their network

# %%
from __future__ import division
from __future__ import print_function
# The %... is an iPython thing, and is not part of the Python language.
# In this case we're just telling the plotting library to draw things on
# the notebook, instead of on a separate window.
# %matplotlib inline
import os
os.getcwd()
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import csv
from collections import Counter
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")


import random
from PIL import Image
from os import path
from nltk.corpus import stopwords
from scipy.misc import imread
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from wordcloud import WordCloud, STOPWORDS

import mysql.connector
from mysql.connector import errorcode
from mysql.connector import Error

import plotly
import networkx as nx
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
plotly.tools.set_credentials_file(username='raunakm90', api_key='qh9wd16d6g')

import plot_network
import plotly.plotly as py
from plotly.graph_objs import *
#sns.set_context("poster")

from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# C:\Users\Raunak Mundada\Anaconda2\lib\site-packages\fuzzywuzzy\fuzz.py:35: UserWarning:
#
# Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning

# %% [markdown]
# ## Import data from SQL database

# %%
import mysql_setup
query_list,field_names = mysql_setup.query_with_fetchmany("SELECT * FROM Author")
Author = mysql_setup.make_frame(query_list,field_names)

# %%
query_list,field_names = mysql_setup.query_with_fetchmany("SELECT * FROM Publishing_Detail")
Publishing_Detail = mysql_setup.make_frame(query_list,field_names)

# %% [markdown]
# ## Extract top authors and their corresponding publications

# %%
ind = Author.Author_Cited_By.sort_values(ascending = False).index
# Select top 4 indices
ind = ind[0:4]
top_Authors = Author[Author.index.isin(ind)]
a_dict = top_Authors.set_index('Author_Id')['Author_Name'].to_dict()
top_Authors
# Out:
#        Author_Id        Author_Name                                 Author_Affiliation      Author_Email                                   Author_Interests  Author_Cited_By  Author_hIndex  Author_i10Index  Author_hIndex_recent  Author_i10Index_recent
# 7   JicYPdAAAAAJ    Geoffrey Hinton  Emeritus Professor of Computer Science, Univer...   @cs.toronto.edu  machine learning,neural networks,artificial in...           133698            120              288                    87                     205
# 18  vtegaJgAAAAJ             vapnik  Professor of Columbia, Fellow of NEC Labs Amer...     @nec-labs.com       machine learning,statistics,computer science           168020            108              372                    73                     278
# 20  yxUduqMAAAAJ  Michael I. Jordan  Professor of EECS and Professor of Statistics,...  @cs.berkeley.edu  machine learning,statistics,computational biol...            99956            129              397                    88                     334
# 21  ZpG_cJwAAAAJ  Robert Tibshirani  Professor of Health Research and Policy, and S...     @stanford.edu  Statistics,Applied Statistics,Statistical lear...           222620            130              336                    94                     283

# %%
#Key_Value pair of author id and author name
a_dict
# Out:
# {u'JicYPdAAAAAJ': u'Geoffrey Hinton',
#  u'ZpG_cJwAAAAJ': u'Robert Tibshirani',
#  u'vtegaJgAAAAJ': u'vapnik',
#  u'yxUduqMAAAAJ': u'Michael I. Jordan'}

# %%
#Get the publications of the required authors
a_id = a_dict.keys()
DB_NAME = 'NLP_Project'
in_p=', '.join(list(map(lambda x: '%s', a_id)))
sql = ("SELECT * FROM publishing_Detail WHERE Author_Id in (%s)")
sql = sql % in_p
query_list = list()
cnx = mysql.connector.connect(user='root',password = "raunak")
cursor = cnx.cursor()
cnx.database = DB_NAME
cursor.execute(sql,a_id)

for row in iter(cursor):
        query_list.append(row)
        num_fields = len(cursor.description)
        field_names = [i[0] for i in cursor.description]
        field_names
        
cursor.close()
cnx.close()
Author_Pubs = mysql_setup.make_frame(query_list,field_names)
Author_Pubs.head()
# Out:
#                       Pub_Id                                          Pub_Title                                        Pub_Authors               Pub_Publisher                      Pub_Journal                                       Pub_Abstract Pub_Volume  Pub_Year  Pub_Citedby                                            Pub_URL     Author_Id
# 0  JicYPdAAAAAJ:-6RzNnnwWf8C                               Pittsburgh, PA 15213    David C Plant,Steven J Now1an,Geoffrey E Hinton                        NULL                             NULL  7 Abstract Rumelhart, Hinton and Williams [Rum...       NULL      1986          -99  https://www.cs.toronto.edu/~hinton/absps/bptr.pdf  JicYPdAAAAAJ
# 1  JicYPdAAAAAJ:-7ulzOJl1JYC                                  Error Propagation  DE Rummelhart,GE Hinton,RJ Williams Learning I...                        NULL  Parallel Distributed Processing                                               NULL       NULL       -99           20  http://scholar.google.com/scholar?cluster=1578...  JicYPdAAAAAJ
# 2  JicYPdAAAAAJ:-DxkuPiZhfEC                                         WJ CLANCEY  S AMAREL,Y ANZAI,HG BARROW,H BERLINER,RS BOYER...                        NULL                             NULL                                               NULL       NULL       -99          -99  http://scholar.google.com/scholar?cluster=6697...  JicYPdAAAAAJ
# 3  JicYPdAAAAAJ:-f6ydRqryjwC  Learning translation invariant recognition in ...                                  Geoffrey E Hinton  Springer Berlin Heidelberg                             NULL  One major goal of research on massively parall...       NULL      1987          177  http://link.springer.com/chapter/10.1007/3-540...  JicYPdAAAAAJ
# 4  JicYPdAAAAAJ:-mN3Mh-tlDkC  E ‘-Jgjfssl ‘-y Cw. 117-tae.\, I987./ttttttttt...                    Geoffrey E Hinton,David C Plaut                        NULL                             NULL  \ Abstract _ Connectionist models usually have...       NULL       -99          -99  https://www.cnbc.pitt.edu/~plaut/papers/pdf/Hi...  JicYPdAAAAAJ

# %%
# Publication of the first author
pubs = Author_Pubs[Author_Pubs['Author_Id']==a_id[0]]

# %% [markdown]
# ## Create author networks

# %% [markdown]
# Collect all co-authors for a given author's publication and count how many times they have co-authored a paper. This way create a adjacency matrix for all connections between the author and his co-authors as well as amongst the co-authors. This will show how the co-authors are connected as well.

# %% [markdown]
# For each graph, hover over the nodes to get details related to that node. Yet to add edge strength (for some reason it seems to be way more complicated than imagined). The size and the colour of the node vary according to the number of connections or the degree of the node.

# %%
# All the co-authors of a given author
x = pubs['Pub_Authors'].tolist()
x_authors = ",".join(unicode(i) for i in x if not i.isdigit())
x_authors = x_authors.lower()

#Create adjacency matrix of author connections
x_authors = set(x_authors.split(","))
adj_mat = pd.DataFrame(0, index=x_authors, columns=x_authors)
for authors in x:
    temp = authors.lower().split(",")
    if len(temp)>1:
        for i in range(0,len(temp)-1):
            j=0
            while j <= len(temp)-1:
                adj_mat[temp[i]][temp[j]] = adj_mat[temp[i]][temp[j]]+1
                j +=1
                
Gr=nx.from_numpy_matrix(adj_mat.values)

G = ((source, target, attr) for source, target, attr in 
                Gr.edges_iter(data=True) if attr['weight'] > 1)
new_network = nx.Graph()
new_network.add_edges_from(G)


position=nx.spring_layout(new_network)
labels = adj_mat.columns[new_network.nodes()]

traceE=plot_network.scatter_edges(new_network, position)
traceN=plot_network.scatter_nodes(new_network,position,labels = labels)

fig = Figure(data=Data([traceE, traceN]),
             layout=Layout(
                title='<br>Network graph - Robert Tibshirani',
                titlefont=dict(size=18),
                showlegend=False, 
                width=1000,
                height=1000,
                margin=dict(b=20,l=5,r=5,t=40),
                hovermode='closest',
                xaxis=XAxis(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=YAxis(showgrid=False, zeroline=False, showticklabels=False)))

iplot(fig, filename='Robert Tibshirani')
# Out:
# <div id="6f1da6ed-08ce-4da1-a0c4-8078a4203822" style="height: 1000px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6f1da6ed-08ce-4da1-a0c4-8078a4203822", [{"text": [], "mode": "lines", "hoverinfo": "text", "y": [0.9694092330123544, 0.9694092330123544, null, 0.42201319098652174, 0.42201319098652174, null, 0.42201319098652174, 0.40032737157726334, null, 0.42201319098652174, 0.4141658624706384, null, 0.42201319098652174, 0.4057324107171987, null, 0.42201319098652174, 0.43057777146695897, null, 0.32002361015093245, 0.3841507082218544, null, 0.32002361015093245, 0.306912274762024, null, 0.32002361015093245, 0.32002361015093245, null, 0.32002361015093245, 0.37001121865834874, null, 0.32002361015093245, 0.34247946907236526, null, 0.32002361015093245, 0.4057324107171987, null, 0.6020303860015327, 0.5307903527682123, null, 0.6020303860015327, 0.6032849760714625, null, 0.6020303860015327, 0.6043646893748486, null, 0.6020303860015327, 0.6514009726904932, null, 0.6020303860015327, 0.5980488836174785, null, 0.6020303860015327, 0.5830689150930614, null, 0.6020303860015327, 0.6128552196127355, null, 0.6020303860015327, 0.5891827437530099, null, 0.6020303860015327, 0.6020303860015327, null, 0.6020303860015327, 0.5817205845391673, null, 0.3920865874532638, 0.4087950897476668, null, 0.3920865874532638, 0.44397645865720103, null, 0.3920865874532638, 0.44190875824316067, null, 0.3920865874532638, 0.39359084002264494, null, 0.3920865874532638, 0.40836478012054456, null, 0.3920865874532638, 0.4453492721956128, null, 0.3920865874532638, 0.4544354704747494, null, 0.3920865874532638, 0.4473661067446325, null, 0.3920865874532638, 0.397760042101339, null, 0.3920865874532638, 0.3920865874532638, null, 0.3920865874532638, 0.40781822264935275, null, 0.3920865874532638, 0.44184475093449904, null, 0.3920865874532638, 0.3953879455256323, null, 0.3920865874532638, 0.43909004961920733, null, 0.3920865874532638, 0.4379911757245658, null, 0.3920865874532638, 0.4145565736955468, null, 0.3920865874532638, 0.40389053657741286, null, 0.3920865874532638, 0.4059945520919543, null, 0.3920865874532638, 0.44414831470569704, null, 0.3920865874532638, 0.3964173001994441, null, 0.3920865874532638, 0.43811552210795396, null, 0.3920865874532638, 0.43888938455468757, null, 0.3920865874532638, 0.45450149838862797, null, 0.3920865874532638, 0.44206688440898495, null, 0.3920865874532638, 0.444820256448915, null, 0.3920865874532638, 0.395998203360271, null, 0.3920865874532638, 0.3875439447298045, null, 0.3920865874532638, 0.4101981936968713, null, 0.3920865874532638, 0.45443140834589457, null, 0.3920865874532638, 0.4342140482830925, null, 0.3920865874532638, 0.40312870477076646, null, 0.3920865874532638, 0.44331398120365256, null, 0.3920865874532638, 0.4508089946390574, null, 0.3920865874532638, 0.44701005815486566, null, 0.3920865874532638, 0.45077034014939016, null, 0.3920865874532638, 0.4464216722428066, null, 0.3920865874532638, 0.40971035776461384, null, 0.3920865874532638, 0.4074662234391592, null, 0.3920865874532638, 0.44719622273245874, null, 0.3920865874532638, 0.4374742162337087, null, 0.3920865874532638, 0.44153457820813513, null, 0.3920865874532638, 0.4448235627371174, null, 0.20570382877922397, 0.20570382877922397, null, 0.20570382877922397, 0.2035384092310675, null, 0.20570382877922397, 0.11964488015134885, null, 0.20570382877922397, 0.1294252571328862, null, 0.20570382877922397, 0.12453926348228368, null, 0.20570382877922397, 0.4057324107171987, null, 0.6231404777750503, 0.6213700507525483, null, 0.6231404777750503, 0.6129611524497319, null, 0.6231404777750503, 0.6231404777750503, null, 0.6639525255273043, 0.5244230454532641, null, 0.6639525255273043, 0.661600733690314, null, 0.6639525255273043, 0.6921723657818402, null, 0.6639525255273043, 0.6756402785552025, null, 0.6639525255273043, 0.6514009726 ...

# %%
x_authors
# Out:
# {u'p herbert leiderman',
#  u'balakanapathy rajaratnam',
#  u'robert j huebner',
#  u'andrew fire',
#  u'emmanuel candes',
#  u'joachim torhorst',
#  u'cantor michael',
#  u'david j inwards',
#  u'rj arceci',
#  u'efron bradley',
#  u'saul a rosenberg',
#  u'eugene i rosanoff',
#  u'd botstein',
#  u'oliver w press',
#  u'ra olshen',
#  u'chi ma',
#  u'matthew w anderson',
#  u't louis',
#  u'jm vose',
#  u'celia mt greenwood',
#  u'wonshik han',
#  u'robert textor',
#  u'jialing zhang',
#  u'max grazier g\u2019sell',
#  u'tarangini deshpande',
#  u'f batliwalla',
#  u'terence tao',
#  u'louis kouadio',
#  u'l tarassenko',
#  u'ephraim m hanks',
#  u'uwe scherf',
#  u'ezequiel martinez',
#  u'brett d arnoldo',
#  u'ellen schlichting',
#  u'roberto herrera-goepfert',
#  u'christine steinhoff',
#  u'l lu',
#  u'nj crellin',
#  u'mia levy',
#  u'inigo espinosa',
#  u'mr chang',
#  u'john c parker',
#  u'jerome friedman',
#  u'mohith sadaram',
#  u'pamela m merrick',
#  u'jean-marc robin',
#  u'tze leung lai',
#  u'p eystein lonning',
#  u'chris marrison',
#  u'millard h lambert',
#  u'ash a alizadeh',
#  u'laura hennessy',
#  u'aihua zhang',
#  u'thomas l sikic',
#  u'weijun qian',
#  u'john ross',
#  u'sanja sale',
#  u'jd minna',
#  u'discussion zehua chen',
#  u'jp molin',
#  u'c crocheti\xe8re',
#  u'ulf bergerheim',
#  u'yasodha natkunam',
#  u'g allen',
#  u'victor m panaretos',
#  u'christina s kong',
#  u'lois m green',
#  u'young h kim',
#  u'douglas hayden',
#  u'david l dill',
#  u'robert j marinelli',
#  u'celeste c finnerty',
#  u'peter m glazer',
#  u'l douglas',
#  u'wr loewenstein',
#  u'wlodzimierz grodecki',
#  u'f behm',
#  u'nicholas cicutti',
#  u'peter ebbesen',
#  u'sushama varma',
#  u'harold brody',
#  u"grant o'keefe",
#  u'maintainer keyan salari',
#  u'julien emile-geay',
#  u'marline pirlet',
#  u'martin j booth',
#  u'is helland',
#  u'alexander j clark',
#  u'steven m strasberg',
#  u'roger a wagner',
#  u'soheir r tawfik',
#  u'herman t blumenthal',
#  u'j hudson jr',
#  u'sylvia k plevritis',
#  u'arup bose',
#  u'amon nagler',
#  u'jp romano',
#  u'li li',
#  u'sg soltys',
#  u'stefanie s jeffrey',
#  u'd mergel',
#  u'peter gm van der heijden',
#  u'v goss',
#  u'l lortie',
#  u'rd gascoyne',
#  u'rossella ferrara',
#  u'jpt higgins',
#  u'richard m myers',
#  u'mu zhu',
#  u'mark m davis',
#  u'jp higgins',
#  u'richard w cottle',
#  u'd camp',
#  u'rmkw lee',
#  u'baiyu zhou',
#  u'matthew zapala',
#  u'michael leblanc',
#  u'g volgyesi',
#  u'robert f luo',
#  u'timothy c greiner',
#  u'donna l thibault',
#  u'richard f ambinder',
#  u'per eystein l\xf8nning',
#  u'joseph verducci',
#  u'matt van de rijn',
#  u'lei sun',
#  u'alan s go',
#  u'julius schachter',
#  u'andrew m evens',
#  u'edward m rubin',
#  u'trevor bailey',
#  u'alvaro macieira-coelho',
#  u'janet l walker',
#  u'collins a karikari',
#  u'dsa nuyten',
#  u'aubrey s outschoorn',
#  u'masoud asgharian',
#  u'thomas m habermann',
#  u'xuhuai ji',
#  u'h tong',
#  u'ma oliver',
#  u'michael j robertson',
#  u'douglas r galasko',
#  u'g shi',
#  u'cornelia l dekker',
#  u'wing c chan',
#  u'tim wiles',
#  u'l\xe9o buhler',
#  u'david g camp',
#  u'a antoniadis',
#  u'cfj wu',
#  u'jaclyn renfrow',
#  u'murali d bashyam',
#  u'hg muller',
#  u'j rucker',
#  u'y ravindranath',
#  u'p hall',
#  u'alan gray',
#  u'jeremy sokolove',
#  u'beren h tomooka',
#  u'p simard',
#  u'philip lavori',
#  u'albert koong',
#  u'se ahmed',
#  u'arnon nagler',
#  u'izidore lossos',
#  u'jun chen',
#  u'robert walkup',
#  u'pritam ranjan',
#  u'rb west',
#  u'p kinnunen',
#  u'richard w norman',
#  u'wayne a fuller',
#  u'jf macgregor',
#  u'branimir sikic',
#  u'maintainer balasubramanian narasimhan',
#  u'laurent salmon',
#  u'h llewellyn-thomas',
#  u'yz wang',
#  u'laurie h sehn',
#  u'diane m sullenberger',
#  u'w scott beattie',
#  u'amato j giaccia',
#  u'yh kim',
#  u'javier catal\xe1n',
#  u'yue wan',
#  u'yunjin choi',
#  u'michel tenenhaus',
#  u'pl speckman',
#  u'elizabeth weinzierl',
#  u'martin bast',
#  u'mevin b hooten',
#  u'farid f abraham',
#  u'marc lipsitch',
#  u'h sabet',
#  u'h shaw warren',
#  u'iain m johnstone',
#  u'jacob bien',
#  u'jason lo',
#  u'peter m hwang',
#  u'paivi kinnunen',
#  u'r southworth',
#  u'gabor lugosi',
#  u'shoshana levy',
#  u'pf armstrong',
#  u'hui zou',
#  u'jean-francois beaumont',
#  u'doug ross',
#  u'fg behm',
#  u'rm neal',
#  u'lm cooney jr',
#  u'tony wilson',
#  u'r viveros',
#  u'larry wasserman',
#  u'discussion charles j stone',
#  u'discussion leo breiman',
#  u'christine williams',
#  u'nicolas remy',
#  u'laurence g rahme',
#  u'eric jonasch',
#  u'c willman',
#  u'william he day',
#  u'yudong d he',
#  u'xiangyu xiao',
#  u'y ji',
#  u'ronald tompkins',
#  u'w buntine',
#  u'per skaane',
#  u'kenneth f schulz',
#  u'anna karydas',
#  u'jaclyn j renfrow',
#  u'ab miller',
#  u'wei z ai',
#  u'daniela witten',
#  u'raviprakash tumkur sitaram',
#  u'robert a hromas',
#  u'b narasimhan',
#  u'alan kimber',
#  u'adrienne c scheck',
#  u'y fradet',
#  u'jim mohr',
#  u'griffith r harsh',
#  u'b talisse robert',
#  u'william nantau',
#  u'sylvia plevritis',
#  u'm chang',
#  u'piyanka e chandra',
#  u'r mchugh',
#  u'jeffrey s rosenthal',
#  u'christian a rees',
#  u'markus zuber',
#  u'herbert kaizer',
#  u'william j welch',
#  u'deborah f bell',
#  u'joerg schlingemann',
#  u'jt kent',
#  u'maria helena silva-filha',
#  u'torgny rasmuson',
#  u'cariad chester',
#  u'michael eisen',
#  u'po brown',
#  u'cj darken',
#  u'steve e calvano',
#  u'nicholas j turro',
#  u'youn h kim',
#  u'anjali morales',
#  u'dennis richling',
#  u'jared tinklenberg',
#  u'aalim m weljie',
#  u'tina hernandez\u2010boussard',
#  u'g wahba',
#  u'xiao\u2010song he',
#  u'accessing euclid',
#  u'elisha moses',
#  u't mildenberger',
#  u'maintainer gen nowak',
#  u'jine-phone chou',
#  u'ph kinnunen',
#  u'karen raymer',
#  u'r shinghal',
#  u'philip i robles',
#  u'carl e rasmussen',
#  u'joanne carrier',
#  u'howard weinstein',
#  u'richard whyte',
#  u'arvin m gouw',
#  u'discussion rl eubank',
#  u'wojtek krzanowski',
#  u'va funari',
#  u'l tian',
#  u'wh robinson',
#  u'jeffrey a kaye',
#  u'henry s kaplan',
#  u'r beran',
#  u'rd deveaux',
#  u'david bodian',
#  u'dennis j kuo',
#  u'james a lederer',
#  u'jl br\xe9das',
#  u'ar rogers',
#  u'ranjana h advani',
#  u'anita langer\xf8d',
#  u'da redelmeier',
#  u'daniel r richards',
#  u'a ciampi',
#  u'jinko graham',
#  u'david herndon',
#  u'javier briones',
#  u'jc boldrick',
#  u'shirley zhu',
#  u'anne cp lui',
#  u's meshinchi',
#  u'd michie',
#  u'j sunil rao',
#  u'john d mitchell',
#  u'shibing deng',
#  u't thorsen',
#  u'm de kock',
#  u'jiajia zhang',
#  u'deirdre j lyell',
#  u'wan-jen hong',
#  u'paul m gallop',
#  u'carol a francisco',
#  u's efromovitch',
#  u'cheng yong tang',
#  u'alan sandier',
#  u'youngran ji',
#  u'anthony c davison',
#  u'paul j utz',
#  u'johanna g neslehova',
#  u'janos demeter',
#  u'stuart wexler',
#  u'peter j bickel',
#  u'scott soltys',
#  u'frank g rucker',
#  u'lu tian',
#  u'craig giacomini',
#  u'i-ping tu',
#  u'randall s singer',
#  u'gerald masover',
#  u'w hueber',
#  u'n nolan',
#  u'joseph p minei',
#  u'marie morris',
#  u'johnson cs ngan',
#  u'david naylor',
#  u'jaqueline chu',
#  u'ebr desapriya',
#  u'scott g soltys',
#  u'ossi r k\xf6chli',
#  u'weihong xu',
#  u'pl davies',
#  u'christian jodoin',
#  u'james p chandler',
#  u'david schiff',
#  u'nicholas r cozzarelli',
#  u'david levens',
#  u'marci e schaner',
#  u'philip siekevitz',
#  u'avaleigh milne',
#  u'carlos iribarren',
#  u'adam arkin',
#  u'holbrook e kohrt',
#  u'grace wahba',
#  u'ronald f van vollenhoven',
#  u'amer abouhamze',
#  u'christina wolfson',
#  u'jon lampa',
#  u'david pauron',
#  u'ds cross',
#  u'balasubramanian narasimhan',
#  u'd hinkley',
#  u'hwan geun choi',
#  u'alex comfort',
#  u'grant o\u2019keefe',
#  u'gad getz',
#  u'lezlie a derber',
#  u'rachel hovde',
#  u'erwin neter',
#  u'abraham avigdor',
#  u'b lucier',
#  u'joanna mills flemming',
#  u'konstanze d\xf6hner',
#  u'babak shahbaba',
#  u'jh reese',
#  u'carole vogler',
#  u'discussion walter gander',
#  u'j katz',
#  u'theodore r reiff',
#  u'michael a west',
#  u'dany l c\xf4t\xe9',
#  u'trevor hastie',
#  u'john pa ioannidis',
#  u'einar andreas r\xf8dland',
#  u'jlg de paz',
#  u'a sandier',
#  u'jos\xe9 m gualberto',
#  u'luis de sisternes',
#  u'ra marottoli',
#  u'ed kolaczyk',
#  u'ac davison',
#  u'r brooks',
#  u'sam guoping gu',
#  u'ida rk bukholm',
#  u'avery b nathens',
#  u'nicholas m perry',
#  u'r levy',
#  u'ernest e moore',
#  u'peter j duffy',
#  u'james a torchia',
#  u'kerri e rieger',
#  u'maintainer daniela witten',
#  u'r wahab',
#  u'matthew b hale',
#  u'paul a monach',
#  u'wing hung wong',
#  u's levy',
#  u'chong gu',
#  u'angelo m demarzo',
#  u'p butterworth',
#  u'shai shen-orr',
#  u'noreen dowd',
#  u'christopher j yarnell',
#  u'vincent v hamparian',
#  u'kelli d montgomery',
#  u'lm staudt',
#  u'elena cortizas',
#  u'koen jochmans',
#  u'yves claprood',
#  u'tony babinec',
#  u'steven m horvath',
#  u'markus britschgi',
#  u'sumit shah',
#  u'ronald christensen',
#  u'ryan bair',
#  u'david l becton',
#  u'david n herndon',
#  u'jeffrey a norton',
#  u'paul utz',
#  u'laura le cowen',
#  u"discussion finbarr o'sullivan",
#  u'theodore leng',
#  u'john c matese',
#  u'maruse sadek',
#  u'alan h menkis',
#  u'h dohner',
#  u'hj sutherland',
#  u'g walther',
#  u'd irwin',
#  u'kai-wang ng',
#  u'ali salim',
#  u'jean-pierre t\xe9trault',
#  u'jagadish c ghosh',
#  u'geoffrey m silver',
#  u'aj burnham',
#  u'tp hutchinson',
#  u'richard t hoppe',
#  u'tom diciccio',
#  u'a fisher',
#  u'dt wong',
#  u'm fero',
#  u'andrew p weng',
#  u'm joanne douglas',
#  u'julie marie matthews',
#  u'mh neumann',
#  u'mark a wechser',
#  u'rafal kustra',
#  u'garry p nolan',
#  u'ab owen',
#  u'discussion george k golubev',
#  u'h quist',
#  u'zhiliang ying',
#  u'jiehui li',
#  u'stephen p boyd',
#  u'ls lossos',
#  u'jessica donington',
#  u'ga young',
#  u'harris fienberg',
#  u'ajay k yadav',
#  u'r tibshirani',
#  u'christopher r king',
#  u'brown pat',
#  u'gen nowak',
#  u'roch houot',
#  u'gi barenblatt',
#  u'rjitcbdsrpi tibshirani',
#  u'simon j sheather',
#  u'chih long liu',
#  u'ian campbell',
#  u'rahul mazumder',
#  u'zhen fan',
#  u'david satcher',
#  u'michael s lauer',
#  u'patrizia berti',
#  u'allen liss',
#  u'minnie sarwal',
#  u'dan w denney',
#  u'hongjuan zhao',
#  u'a rosenwald',
#  u'pe lonning',
#  u'maintainer trevor hastie',
#  u'km wang',
#  u'deva thiruchelvam',
#  u'marwan n sabbagh',
#  u'dh wolpert',
#  u'matthieu vermel',
#  u'giuseppe ciaravino',
#  u'walter rayford',
#  u'qx le',
#  u'b tan',
#  u'james o armitage',
#  u'phillip w lavori',
#  u'janine r roper',
#  u'alexander yabrov',
#  u'jo carroll-munro',
#  u'stefan wager',
#  u'anatoly langer',
#  u'jean-pierre molin',
#  u'debra k czerwinski',
#  u'david furman',
#  u'timothy b baker',
#  u'bernd bodenmiller',
#  u'john l hunt',
#  u'philip s tsao',
#  u'cp giacomini',
#  u'dan viskari',
#  u'james brooks',
#  u'scott d boyd',
#  u'robert j tibshirani',
#  u'b tomooka',
#  u'jd brooks',
#  u'mb eisen',
#  u'toshiharu matsumura',
#  u'tibshirani robert',
#  u'zongming ma',
#  u'an sandler',
#  u'shane t jensen',
#  u'i nobutada',
#  u'lennart minthon',
#  u'june h myklebust',
#  u'e herrmann',
#  u'z ghahramani',
#  u'stephen f lowry',
#  u'sandra caldeira',
#  u'md fiore',
#  u'bret larget',
#  u'michael i jordan',
#  u'mark c genovese',
#  u'challa v kumar',
#  u'joshua r loftus',
#  u'matthew p salzberg',
#  u'michael cantor',
#  u'tyzoon k nomanbhoy',
#  u'p doukhan',
#  u'b ljungberg',
#  u'ginette schiby',
#  u'wl jungers',
#  u'dch cheng',
#  u'm nussbaum',
#  u'michael revow',
#  u'h lin',
#  u'cd lai',
#  u'todd chedore',
#  u'daniel g remick',
#  u'zhengqing ouyang',
#  u'gr andrews',
#  u'robart tibshirani',
#  u'h liu',
#  u'd larry sparks',
#  u'rp tracy',
#  u'jack gambino',
#  u'd gratzinger',
#  u'maria lucia s g\xfcther',
#  u'bernard h brownstein',
#  u'j kononen',
#  u'robert g green',
#  u'lori a kunkel',
#  u'r bordes',
#  u'd draper',
#  u'herbert schwartz',
#  u'bernard l strehler',
#  u'trevor hastie robert tibshirani',
#  u'dj cuillerier',
#  u'neema jamshidi',
#  u'jonathan e taylor',
#  u'brian milne',
#  u'nathalie a johnson',
#  u'troyanskaya olga',
#  u'jb gray',
#  u'o kallioniemi',
#  u'robert e reiter',
#  u'cheryl l smith',
#  u'joe horecka',
#  u'franak batliwalla',
#  u'ron levy',
#  u'lauren j lahey',
#  u'michael r grever',
#  u'manuel rosado',
#  u'kayh brodersen',
#  u'peter k jackson',
#  u'd thiruchelvam',
#  u'stephen halpern',
#  u'h li',
#  u'roger a warnke',
#  u'david e tyler',
#  u'richard j cook',
#  u'david r brillinger',
#  u'p babyn',
#  u'ta glass',
#  u'teresa l wright',
#  u'j engel',
#  u'nathan mantel',
#  u'diane e ingolia',
#  u'weiyun ai',
#  u'odd terje brustugun',
#  u's edelstein',
#  u'benedict anchang',
#  u'jocelyn sutton posthumus',
#  u'di ta gratzinger',
#  u'charlotte jacobs',
#  u'janine t erler',
#  u'gongyi shi',
#  u'samuel kotz',
#  u'diana arsenieva',
#  u'jeffrey v matous',
#  u'j parker',
#  u'giovanni parmigiani',
#  u's srinivas',
#  u'ca mccarty',
#  u'di cook',
#  u'drew van camp',
#  u'b efron',
#  u'jonathan r pollack',
#  u'holger dieterich',
#  u'lewis thomas',
#  u'a harwood',
#  u'neha talreja',
#  u'rui li',
#  u'stephen reid',
#  u'juan carlos del valle',
#  u'cj yarnell',
#  u'thomas jules diciccio',
#  u'hilary llewellyn-thomas',
#  u'noah simon',
#  u'brian g harbrecht',
#  u'jeffrey johnson',
#  u'kevin d deane',
#  u'alexander schoenhuth',
#  u'td wong',
#  u'florencia leonardi',
#  u'john spinelli',
#  u'john allen',
#  u'alejandro mohar',
#  u'pierre-alain clavien',
#  u'b seifert',
#  u'dong-young noh',
#  u'eric d hsi',
#  u'samuel goldstein',
#  u'susan j knox',
#  u'paul f glenn',
#  u'geoffrey e hinton',
#  u't roberts',
#  u'robert lowsky',
#  u'arnold s freedman',
#  u'holly muir',
#  u'td stanley',
#  u'jun li',
#  u'tony wyss-coray',
#  u'haiming zhou',
#  u'marguerite ennis',
#  u'wentian li',
#  u'rejoinder jerome h friedman',
#  u'james e till',
#  u'shari honari',
#  u'qg zhang',
#  u'm maclure',
#  u'christopher k wikle',
#  u'timothy hanson',
#  u'simon j graham',
#  u'jon c aster',
#  u'cheryl willman',
#  u'genevera i allen',
#  u'clare trachuk',
#  u'm van de rijn',
#  u'leslie m zatz',
#  u'narendra singh',
#  u'larry a wasserman',
#  u'gilbert saporta',
#  u'adam olshen',
#  u'guido sauter',
#  u'stefan fr\xf6hling',
#  u'ac koong',
#  u'alexander von eye',
#  u'd van camp',
#  u'jacques couture',
#  u'donald m pace',
#  u'neil risch',
#  u'jonathan pollack',
#  u'ab tsybakov',
#  u'kazuyoshi saito',
#  u'kelli montgomery',
#  u'mark a hlatky',
#  u'ida k bukholm',
#  u'ernest kuwert',
#  u'm wand',
#  u'simon fredriksson',
#  u'philip h mason',
#  u'jacques lapointe',
#  u'ingo ruczinski',
#  u'craig p giacomini',
#  u'james stephen marron',
#  u'trevor j hastie',
#  u'john higgins',
#  u'leah f friedman',
#  u'chiaojung jillian tsai',
#  u'samuel abraham',
#  u'ulysses gj balis',
#  u'myron chang',
#  u'jureta horton',
#  u'james birren',
#  u'david a schoenfeld',
#  u'cy okada',
#  u'andreas buja',
#  u'dennis d weisenburger',
#  u'peter hall',
#  u'omkar muralidharan',
#  u'ss jeffrey',
#  u'alia zaka',
#  u'xin yu',
#  u'jon d mcauliffe',
#  u'e bair',
#  u'tc greiner',
#  u'jim ramsay',
#  u'alessandro rinaldo',
#  u'angela landrigan',
#  u'rejoinder andreas buja',
#  u'aj baczkowski',
#  u'jr pollack',
#  u'boaz nadler',
#  u'marcia s ponce de le\xf3n',
#  u'shlomo rottem',
#  u'praveen sharma',
#  u'jeannette guarner',
#  u'keyan salari',
#  u'g bepler',
#  u'heather wakelee',
#  u'francis w zwiers',
#  u'ds harrington',
#  u't moore',
#  u'shmuel razin',
#  u'kv mardia',
#  u'g lefevre',
#  u't hernandez-boussard',
#  u'michael aj ferguson',
#  u'd redelmeier',
#  u'jerald p radich',
#  u'm-y arsenault',
#  u'kara a fulton',
#  u'jd hart',
#  u'daniela mottel witten',
#  u'n keiding',
#  u'he daniels',
#  u'morris pollard',
#  u'joseph cuschieri',
#  u'n talrega',
#  u"dp o'leary",
#  u'yoav zemel',
#  u'ruth weg',
#  u'jerome h friedman',
#  u'xiaotong suo',
#  u'stephen lowry',
#  u'matthew b klein',
#  u'elaine m brody',
#  u'ma luszcz',
#  u'ce rasmussen',
#  u'david r bellhouse',
#  u'q le',
#  u'douglas l hayden',
#  u'john a mannick',
#  u'howell tong',
#  u'cjf ter braak',
#  u'm stone',
#  u'stephen p fortmann',
#  u'michael n mindrinos',
#  u'robert v bruggner',
#  u'gail mckeown\u2010eyssen',
#  u'saharan rosset',
#  u'john i powell',
#  u'marjan vidmar',
#  u'richard lockhart',
#  u'geoffrey s hawboldt',
#  u'wg williams',
#  u'sudeep banerjee',
#  u'j allen',
#  u'z zheng',
#  u'dg huntsman',
#  u'leland wilkinson',
#  u'scott powers',
#  u'stephen j galli',
#  u'claude a tr\xe9panier',
#  u'qiuling he',
#  u'mark duchaineau',
#  u'dejan juric',
#  u'colette boskovic',
#  u'leslie orgel',
#  u'nathanael s gray',
#  u'd fouskakis',
#  u'stephen farmer',
#  u'p wang',
#  u'nicholas perry',
#  u'arend sidow',
#  u'js shiner',
#  u'm jewett',
#  u'dmax roundhill',
#  u'derek b boothroyd',
#  u'irshad chaudry',
#  u'nadine hussami',
#  u'bu khan',
#  u'raquel malumbres',
#  u'li tan',
#  u'robert c nutter',
#  u'zoubin ghahramani',
#  u'rick a finch',
#  u'ronald m davis',
#  u'sc josephson',
#  u'antonio ciampi',
#  u'denis noble',
#  u'john weinstein',
#  u'thomas quertermous',
#  u'brian k link',
#  u'joseph f quinn',
#  u'imtiaz hossain',
#  u'j carroll-munro',
#  u'mrinmoy sanyal',
#  u'm hansen',
#  u'pei wang',
#  u'cm perou',
#  u'hui jiang',
#  u'da da silva filho',
#  u'isabelle darboux',
#  u'j kay',
#  u'kristine wilson-yang',
#  u'guenther walther',
#  u'heather turner',
#  u'shweta jain',
#  u'richard d smith',
#  u'mark seager',
#  u'eunice chen',
#  u'wyndham wilson',
#  u'botstein david',
#  u'david m jablons',
#  u'joshua d brody',
#  u'n reid',
#  u'dominik e uehlinger',
#  u'jean tang',
#  u'discussion andreas \u0432\u0448\u0430',
#  u'bx shen',
#  u'xiangqian guo',
#  u'dd weisenburger',
#  u'geoffrey hinton',
#  u'jp calbert',
#  u'fj aranda-ordaz',
#  u'sameer malhotra',
#  u'j cornil',
#  u'mike fero',
#  u'jinyuan chang',
#  u'bjarne andresen',
#  u'rk warrian',
#  u'zhishi wang',
#  u'ash alizadeh',
#  u'rj cohen',
#  u'pd sutphin',
#  u'ai castro',
#  u'elena cubedo',
#  u'daniel navi',
#  u'mitchell cohen',
#  u'muin j khoury',
#  u'lowen y lee',
#  u'p gregersen',
#  u'karen m vasquez',
#  u'leonard a stefanski',
#  u'juan r sanabria',
#  u'aa georgiev',
#  u'jill m norris',
#  u'p whittle',
#  u'jp radich',
#  u'ricardo fraiman',
#  u'wei yun ai',
#  u'r warnke',
#  u'r kustra',
#  u'joseph l melnick',
#  u'jamal a alhashemi',
#  u'dita gratzinger',
#  u'nic denko',
#  u'xiao-song he',
#  u'lester packer',
#  u'paul j villeneuve',
#  u'discussion robert kohn',
#  u'craig f ansley',
#  u'bruce l miller',
#  u'cb gilks',
#  u'grant e o\u2019keefe',
#  u'joshua m spin',
#  u'ragini shyam',
#  u'michael d kuo',
#  u'jahn m nesland',
#  u'allan granoff',
#  u'suvarna bhamre',
#  u'j briones',
#  u'david t wong',
#  u'howard j weinstein',
#  u'd darby',
#  u'jerome a yesavage',
#  u'steven l scott',
#  u'hilary c hillier',
#  u'michael j fero',
#  u'harry b greenberg',
#  u'l sommer',
#  u'persi diaconis',
#  u"max grazier g'sell",
#  u'john p leonard',
#  u'ph garthwaite',
#  u'david cox',
#  u'a lagmiche',
#  u'patrick brown',
#  u'wei yon z ai',
#  u'lars bullinger',
#  u'leonard evans',
#  u'c mccudden',
#  u'steven buck',
#  u'sheren f younes',
#  u'gil d rabinovici',
#  u'richard smith',
#  u'martin r lessard',
#  u't sorlie',
#  u'davy cheng',
#  u's geisler',
#  u'discussion dennis d cox',
#  u'douglas t ross',
#  u'dv lindley',
#  u'r neal',
#  u'alec j glassford',
#  u'lauren abrey',
#  u'kai-tai fang',
#  u"ken o'byrne",
#  u'julie b sneddon',
#  u'yichao wu',
#  u'bm psaty',
#  u'daniel l rubin',
#  u'g chu',
#  u'richard l gamelli',
#  u'bharathi lingala',
#  u'wenxin jiang',
#  u'tong zhang',
#  u'george e duran',
#  u'f critchley',
#  u'steven m chan',
#  u'bin yu',
#  u'gary van houten dahl',
#  u'dana bangs',
#  u'a buja',
#  u'kun qu',
#  u'h eric xu',
#  u'l ryner',
#  u'william r gilliland',
#  u'sequoia hall',
#  u'william robinson',
#  u'hanne skomedal',
#  u'cecilia m l\xf3pez',
#  u'heihachi itoh',
#  u'h guanghong',
#  u'cs williams',
#  u'dy noh',
#  u'aijaz ahmed',
#  u'berend snel',
#  u'seyed e hasnain',
#  u'zhongming ma',
#  u'michael falk',
#  u'f neil mckenzie',
#  u'shai s shen-orr',
#  u'douglas e schaubel',
#  u'pedro farinha',
#  u'pierre lavallee',
#  u'apinya buranaprapuk',
#  u'j bruce smith',
#  u'michael j bronskill',
#  u'rw carlson',
#  u'christian genest',
#  u'dean w felsher',
#  u'jose w ruiz',
#  u'kenneth r fulton',
#  u'alejandro jara',
#  u'atul j butte',
#  u'cheryl healton mea',
#  u'vladimir jojic',
#  u'shelley b bull',
#  u'paul w armstrong',
#  u'wing h wong',
#  u'wendell o challenger',
#  u'donna thibault',
#  ...}

# %%
# Publication of the first author
pubs = Author_Pubs[Author_Pubs['Author_Id']==a_dict.keys()[1]]
pubs.head()

# All the co-authors of a given author
x = pubs['Pub_Authors'].tolist()
x_authors = ",".join(unicode(i) for i in x if not i.isdigit())
x_authors = x_authors.lower()

#Create adjacency matrix of author connections
x_authors = set(x_authors.split(","))
adj_mat = pd.DataFrame(0, index=x_authors, columns=x_authors)
for authors in x:
    temp = authors.lower().split(",")
    if len(temp)>1:
        for i in range(0,len(temp)-1):
            j=0
            while j <= len(temp)-1:
                adj_mat[temp[i]][temp[j]] = adj_mat[temp[i]][temp[j]]+1
                j +=1

Gr=nx.from_numpy_matrix(adj_mat.values)

G = ((source, target, attr) for source, target, attr in 
                Gr.edges_iter(data=True) if attr['weight'] > 1)
new_network = nx.Graph()
new_network.add_edges_from(G)


position=nx.spring_layout(new_network)
labels = adj_mat.columns[new_network.nodes()]
     
traceE=plot_network.scatter_edges(new_network, position)
traceN=plot_network.scatter_nodes(new_network,position,labels = labels)

fig = Figure(data=Data([traceE, traceN]),
             layout=Layout(
                title='<br>Network graph - '+str(a_dict.values()[1]),
                titlefont=dict(size=18),
                showlegend=False, 
                width=1000,
                height=750,
                margin=dict(b=20,l=5,r=5,t=40),
                hovermode='closest',
                xaxis=XAxis(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=YAxis(showgrid=False, zeroline=False, showticklabels=False)))

iplot(fig, filename=str(a_dict.values()[1]))
# Out:
# <div id="3ccc7a62-90b3-4459-a540-5797bec50f00" style="height: 750px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3ccc7a62-90b3-4459-a540-5797bec50f00", [{"text": [], "mode": "lines", "hoverinfo": "text", "y": [0.5589195489883423, 0.5589195489883423, null, 0.5589195489883423, 0.5524691939353943, null, 0.5589195489883423, 0.5347533226013184, null, 0.5589195489883423, 0.5615326762199402, null, 0.689936637878418, 0.6720236539840698, null, 0.670686662197113, 0.6720236539840698, null, 0.44264549016952515, 0.4605581760406494, null, 0.44264549016952515, 0.4527631998062134, null, 0.44264549016952515, 0.45279446244239807, null, 0.4431329071521759, 0.4605581760406494, null, 0.4431329071521759, 0.4431329071521759, null, 0.4431329071521759, 0.4377039968967438, null, 0.4431329071521759, 0.43675923347473145, null, 0.4431329071521759, 0.44131332635879517, null, 0.5484112501144409, 0.5553941130638123, null, 0.5484112501144409, 0.5533878207206726, null, 0.5484112501144409, 0.5476182103157043, null, 0.5484112501144409, 0.5471546649932861, null, 0.5484112501144409, 0.5497667193412781, null, 0.5484112501144409, 0.5521398186683655, null, 0.5484112501144409, 0.5484112501144409, null, 0.5484112501144409, 0.5457032918930054, null, 0.5484112501144409, 0.5500775575637817, null, 0.5484112501144409, 0.5347533226013184, null, 0.4840095341205597, 0.49199068546295166, null, 0.4840095341205597, 0.4932844042778015, null, 0.4840095341205597, 0.5067697167396545, null, 0.4840095341205597, 0.4909789562225342, null, 0.4840095341205597, 0.48131638765335083, null, 0.4840095341205597, 0.4989025294780731, null, 0.4840095341205597, 0.49436238408088684, null, 0.4840095341205597, 0.4605581760406494, null, 0.4840095341205597, 0.45777249336242676, null, 0.4840095341205597, 0.49388185143470764, null, 0.47296756505966187, 0.46924442052841187, null, 0.47296756505966187, 0.4661920368671417, null, 0.47296756505966187, 0.48131638765335083, null, 0.47296756505966187, 0.47296756505966187, null, 0.47296756505966187, 0.46708911657333374, null, 0.47296756505966187, 0.46355700492858887, null, 0.698237955570221, 0.6720236539840698, null, 0.6880254745483398, 0.6720236539840698, null, 0.5000172257423401, 0.49626070261001587, null, 0.5000172257423401, 0.492417573928833, null, 0.5000172257423401, 0.5000172257423401, null, 0.5000172257423401, 0.4967353343963623, null, 0.5000172257423401, 0.4872591197490692, null, 0.6867470145225525, 0.6720236539840698, null, 0.6389858722686768, 0.6389858722686768, null, 0.6389858722686768, 0.6428013443946838, null, 0.6389858722686768, 0.6415303945541382, null, 0.6389858722686768, 0.6397432684898376, null, 0.6389858722686768, 0.639137327671051, null, 0.6389858722686768, 0.6410780549049377, null, 0.6389858722686768, 0.6086990237236023, null, 0.6389858722686768, 0.6720236539840698, null, 0.46924442052841187, 0.48131638765335083, null, 0.46924442052841187, 0.46924442052841187, null, 0.46924442052841187, 0.4661920368671417, null, 0.46924442052841187, 0.46355700492858887, null, 0.4963392913341522, 0.48693135380744934, null, 0.4963392913341522, 0.4932844042778015, null, 0.4963392913341522, 0.4848838150501251, null, 0.4963392913341522, 0.49199068546295166, null, 0.4963392913341522, 0.4909789562225342, null, 0.4963392913341522, 0.5067697167396545, null, 0.4963392913341522, 0.4989025294780731, null, 0.4963392913341522, 0.49436238408088684, null, 0.4963392913341522, 0.49591100215911865, null, 0.4963392913341522, 0.49388185143470764, null, 0.4963392913341522, 0.4963392913341522, null, 0.7382321953773499, 0.70875084400177, null, 0.6772369146347046, 0.6720236539840698, null, 0.46916165947914124, 0.4724317193031311, null, 0.46916165947914124, 0.4653673768043518, null, 0.46916165947914124, 0.47055160999298096, null, 0.46916165947914124, 0.46735015511512756, null, 0.4786011874675751, 0.49199068546295166,  ...

# %%
# Publication of the first author
pubs = Author_Pubs[Author_Pubs['Author_Id']==a_dict.keys()[2]]
pubs.head()

# All the co-authors of a given author
x = pubs['Pub_Authors'].tolist()
x_authors = ",".join(unicode(i) for i in x if not i.isdigit())
x_authors = x_authors.lower()
temp = x_authors.split(",")
print (temp.count(str(a_dict.values()[2])))

#Create adjacency matrix of author connections
x_authors = set(x_authors.split(","))
adj_mat = pd.DataFrame(0, index=x_authors, columns=x_authors)
for authors in x:
    temp = authors.lower().split(",")
    if len(temp)>1:
        for i in range(0,len(temp)-1):
            j=0
            while j <= len(temp)-1:
                adj_mat[temp[i]][temp[j]] = adj_mat[temp[i]][temp[j]]+1
                j +=1

Gr=nx.from_numpy_matrix(adj_mat.values)

G = ((source, target, attr) for source, target, attr in 
                Gr.edges_iter(data=True) if attr['weight'] > 1)
new_network = nx.Graph()
new_network.add_edges_from(G)


position=nx.spring_layout(new_network)
labels = adj_mat.columns[new_network.nodes()]
     
traceE=plot_network.scatter_edges(new_network, position)
traceN=plot_network.scatter_nodes(new_network,position,labels = labels)

fig = Figure(data=Data([traceE, traceN]),
             layout=Layout(
                title='<br>Network graph - '+str(a_dict.values()[2]),
                titlefont=dict(size=18),
                showlegend=False, 
                width=1000,
                height=750,
                margin=dict(b=20,l=5,r=5,t=40),
                hovermode='closest',
                xaxis=XAxis(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=YAxis(showgrid=False, zeroline=False, showticklabels=False)))

iplot(fig, filename=str(a_dict.values()[2]))
# Out:
# 0
# <div id="d068978e-7fd9-498d-9c04-94a816251926" style="height: 750px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d068978e-7fd9-498d-9c04-94a816251926", [{"text": [], "mode": "lines", "hoverinfo": "text", "y": [0.5687061855528851, 0.5687061855528851, null, 0.5687061855528851, 0.5290814398819454, null, 0.5687061855528851, 0.536666508385189, null, 0.5687061855528851, 0.5123232289891991, null, 0.5687061855528851, 0.5506988913486683, null, 0.5687061855528851, 0.5485094100130958, null, 0.5687061855528851, 0.5248736867767216, null, 0.5687061855528851, 0.5109212271606313, null, 0.5687061855528851, 0.547853448179449, null, 0.5687061855528851, 0.5230619603338611, null, 0.5687061855528851, 0.5668416844622879, null, 0.5687061855528851, 0.503897716072932, null, 0.5687061855528851, 0.5193032133655096, null, 0.5687061855528851, 0.5355710200834778, null, 0.5687061855528851, 0.5423101585525284, null, 0.5687061855528851, 0.508290153861325, null, 0.5687061855528851, 0.52966639453719, null, 0.5687061855528851, 0.5142630695184287, null, 0.5687061855528851, 0.5107786669784978, null, 0.5687061855528851, 0.5394109082723951, null, 0.5687061855528851, 0.5117170669660602, null, 0.5687061855528851, 0.5035392823728565, null, 0.5687061855528851, 0.5529560261581655, null, 0.5687061855528851, 0.5101861753289788, null, 0.5687061855528851, 0.525220558402282, null, 0.5687061855528851, 0.5476297362065375, null, 0.5687061855528851, 0.5035134313917726, null, 0.5687061855528851, 0.5660339378516696, null, 0.5687061855528851, 0.5134356055979024, null, 0.5687061855528851, 0.5609974716613261, null, 0.5687061855528851, 0.553676617793154, null, 0.5687061855528851, 0.561687230049619, null, 0.5687061855528851, 0.526565419454462, null, 0.5687061855528851, 0.5291029824302481, null, 0.5687061855528851, 0.51035780323276, null, 0.5687061855528851, 0.5105392034301094, null, 0.5687061855528851, 0.5126807528970291, null, 0.5687061855528851, 0.516771942543318, null, 0.5687061855528851, 0.5120007422141724, null, 0.5687061855528851, 0.5143530077168501, null, 0.5687061855528851, 0.5224792043524726, null, 0.10126601818499707, 0.3004363160692413, null, 0.4728984304381142, 0.503897716072932, null, 0.4728984304381142, 0.49922900638023304, null, 0.4728984304381142, 0.4728984304381142, null, 0.4728984304381142, 0.4480789234937724, null, 0.4728984304381142, 0.4882847617035162, null, 0.4728984304381142, 0.48538473175274105, null, 0.4728984304381142, 0.4831246554182895, null, 0.4728984304381142, 0.491150825981668, null, 0.4728984304381142, 0.5035134313917726, null, 0.4728984304381142, 0.4572184414132315, null, 0.4728984304381142, 0.48780448837930146, null, 0.4728984304381142, 0.5109212271606313, null, 0.4728984304381142, 0.490138310666065, null, 0.4728984304381142, 0.5123232289891991, null, 0.4728984304381142, 0.4919422666070864, null, 0.4728984304381142, 0.46715898681659207, null, 0.4728984304381142, 0.47894025822427877, null, 0.4728984304381142, 0.49586106158404647, null, 0.4728984304381142, 0.5193032133655096, null, 0.4728984304381142, 0.4817863064067735, null, 0.4728984304381142, 0.508290153861325, null, 0.4728984304381142, 0.5143530077168501, null, 0.4728984304381142, 0.5142630695184287, null, 0.4728984304381142, 0.5107786669784978, null, 0.4728984304381142, 0.5117170669660602, null, 0.4728984304381142, 0.4993573256941667, null, 0.4728984304381142, 0.46610727197655855, null, 0.4728984304381142, 0.48247353026548, null, 0.4728984304381142, 0.49054563186693717, null, 0.4728984304381142, 0.5101861753289788, null, 0.4728984304381142, 0.510011782885849, null, 0.4728984304381142, 0.4649798880323717, null, 0.4728984304381142, 0.4787198440205204, null, 0.4728984304381142, 0.525220558402282, null, 0.4728984304381142, 0.4943989205364344, null, 0.4728984304381142, 0.48365628632359836, null, 0.4728984304381142, 0.5134356055979024,  ...

# %%
# Publication of the first author
pubs = Author_Pubs[Author_Pubs['Author_Id']==a_dict.keys()[3]]
pubs.head()

# All the co-authors of a given author
x = pubs['Pub_Authors'].tolist()
x_authors = ",".join(unicode(i) for i in x if not i.isdigit())
x_authors = x_authors.lower()
temp = x_authors.split(",")
print (temp.count(str(a_dict.values()[3])))

#Create adjacency matrix of author connections
x_authors = set(x_authors.split(","))
adj_mat = pd.DataFrame(0, index=x_authors, columns=x_authors)
for authors in x:
    temp = authors.lower().split(",")
    if len(temp)>1:
        for i in range(0,len(temp)-1):
            j=0
            while j <= len(temp)-1:
                adj_mat[temp[i]][temp[j]] = adj_mat[temp[i]][temp[j]]+1
                j +=1

Gr=nx.from_numpy_matrix(adj_mat.values)

G = ((source, target, attr) for source, target, attr in 
                Gr.edges_iter(data=True) if attr['weight'] > 1)
new_network = nx.Graph()
new_network.add_edges_from(G)


position=nx.spring_layout(new_network)
labels = adj_mat.columns[new_network.nodes()]
     
traceE=plot_network.scatter_edges(new_network, position)
traceN=plot_network.scatter_nodes(new_network,position,labels = labels)

fig = Figure(data=Data([traceE, traceN]),
             layout=Layout(
                title='<br>Network graph - '+str(a_dict.values()[3]),
                titlefont=dict(size=18),
                showlegend=False, 
                width=1000,
                height=750,
                margin=dict(b=20,l=5,r=5,t=40),
                hovermode='closest',
                xaxis=XAxis(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=YAxis(showgrid=False, zeroline=False, showticklabels=False)))

iplot(fig, filename=str(a_dict.values()[3]))
# Out:
# 0
# <div id="211c1eb3-70ed-42f9-b75c-1365d5567e00" style="height: 750px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("211c1eb3-70ed-42f9-b75c-1365d5567e00", [{"text": [], "mode": "lines", "hoverinfo": "text", "y": [0.5436151711267098, 0.5436151711267098, null, 0.5436151711267098, 0.34658586031648014, null, 0.4280446020684362, 0.4886860384314792, null, 0.4280446020684362, 0.4280446020684362, null, 0.4280446020684362, 0.34658586031648014, null, 0.9161806080289584, 0.9161806080289584, null, 0.9161806080289584, 0.9513548835163018, null, 0.9161806080289584, 0.8307945037942651, null, 0.5118244149743492, 0.5089523667061113, null, 0.5118244149743492, 0.5118244149743492, null, 0.5118244149743492, 0.5336655763530685, null, 0.5118244149743492, 0.5000691248485425, null, 0.5118244149743492, 0.49303992787521655, null, 0.5118244149743492, 0.5187460927156081, null, 0.5118244149743492, 0.5383810283265628, null, 0.5118244149743492, 0.5000441729502694, null, 0.5118244149743492, 0.5024444820850018, null, 0.5118244149743492, 0.5249434677914844, null, 0.5118244149743492, 0.5312161671060416, null, 0.5118244149743492, 0.5458986754031235, null, 0.5118244149743492, 0.521134967084588, null, 0.5118244149743492, 0.5272716000988225, null, 0.5118244149743492, 0.49172799890848395, null, 0.5118244149743492, 0.5113533275358887, null, 0.5118244149743492, 0.5275400186300714, null, 0.5118244149743492, 0.5194505850382594, null, 0.5118244149743492, 0.5354052218182873, null, 0.5118244149743492, 0.5139440943507169, null, 0.5118244149743492, 0.5546212848282494, null, 0.5118244149743492, 0.5339030171206346, null, 0.5118244149743492, 0.5184606779145867, null, 0.5118244149743492, 0.5360042519840423, null, 0.5118244149743492, 0.49795996475462817, null, 0.5118244149743492, 0.4999375136503799, null, 0.5118244149743492, 0.5033425413046915, null, 0.5118244149743492, 0.5209919139982976, null, 0.5118244149743492, 0.5180373907873954, null, 0.5118244149743492, 0.5446429778265711, null, 0.5118244149743492, 0.5261123122501131, null, 0.5118244149743492, 0.5436813899452614, null, 0.5118244149743492, 0.5221616422954604, null, 0.5118244149743492, 0.5546847108178885, null, 0.5118244149743492, 0.5444222695313358, null, 0.5118244149743492, 0.5191332032275268, null, 0.5118244149743492, 0.5116601132961138, null, 0.5118244149743492, 0.5046764578332588, null, 0.5118244149743492, 0.5382663805782825, null, 0.5118244149743492, 0.5094070527111553, null, 0.5118244149743492, 0.5546607009626251, null, 0.5118244149743492, 0.49437020112011754, null, 0.5118244149743492, 0.49254785603412293, null, 0.5118244149743492, 0.501228544178491, null, 0.5118244149743492, 0.502884440027007, null, 0.5118244149743492, 0.4922758625240326, null, 0.5118244149743492, 0.5342883709909806, null, 0.5118244149743492, 0.5425345366314387, null, 0.5118244149743492, 0.5381227503840019, null, 0.5118244149743492, 0.5220957840062453, null, 0.5118244149743492, 0.515790957189167, null, 0.5118244149743492, 0.538539362029879, null, 0.5118244149743492, 0.5546971734518118, null, 0.5118244149743492, 0.5415414477809424, null, 0.5118244149743492, 0.5203271986280861, null, 0.5118244149743492, 0.5335272629848704, null, 0.5118244149743492, 0.537051808836933, null, 0.5118244149743492, 0.5361112250829017, null, 0.5118244149743492, 0.5341488586268698, null, 0.5118244149743492, 0.5222783502276599, null, 0.5118244149743492, 0.5480445049538732, null, 0.5118244149743492, 0.5129778726683111, null, 0.5118244149743492, 0.5023436311919203, null, 0.5118244149743492, 0.5102959089871801, null, 0.5118244149743492, 0.49944418661575235, null, 0.5118244149743492, 0.5489204588114919, null, 0.5118244149743492, 0.5159578597987284, null, 0.5118244149743492, 0.5322319549861445, null, 0.5118244149743492, 0.510302013541644, null, 0.5118244149743492, 0.5367719500031884, null, 0.5118244149743492, 0.548925 ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Ideally, these graphs should be like following: One center node of the main author (on whose basis we extract the publications) and connections from that node to the rest of the network or to his co-authors. Currently, because of difference in spellings and the way names are used, we dont see every node connected. We need partial matching of strings, which will bring in it's own errors.
